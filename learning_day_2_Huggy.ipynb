# %%
# %%capture
# Clone the repository (can take 3min)
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !pip install virtualenv
# !virtualenv env

# Removed conda setup steps
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Removed conda environment activation and package installation
# !source /usr/local/bin/activate
# !conda install -q -y --prefix /usr/local python=3.10.12 ujson  # Specify the version here

# Removed environment variable settings
# !export PYTHONPATH=/usr/local/lib/python3.10/site-packages/
# !export CONDA_PREFIX=/usr/local/envs/myenv
# Out:
# ...
# created virtual environment CPython3.13.5.final.0-64 in 128ms
#   creator CPython3Posix(dest=/content/ml-agents/ml-agents/env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# %%capture
# Go inside the repository and install the package (can take 3min)
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget "https://github.com/huggingface/Huggy/raw/main/Huggy.zip" -O ./trained-envs-executables/linux/Huggy.zip
# Out:
# --2025-10-15 09:05:20--  https://github.com/huggingface/Huggy/raw/main/Huggy.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip [following]
# --2025-10-15 09:05:20--  https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/zip]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M  41.8MB/s    in 0.9s
#
# ...

# %%
# !unzip ./trained-envs-executables/linux/Huggy.zip -d ./trained-envs-executables/linux/
# !chmod -R 755 ./trained-envs-executables/linux/Huggy
# Out:
# Archive:  ./trained-envs-executables/linux/Huggy.zip
#    creating: ./trained-envs-executables/linux/Huggy/
#   inflating: ./trained-envs-executables/linux/Huggy/Huggy.x86_64
#    creating: ./trained-envs-executables/linux/Huggy/Huggy_BurstDebugInformation_DoNotShip/
#    creating: ./trained-envs-executables/linux/Huggy/Huggy_BurstDebugInformation_DoNotShip/Data/
#    creating: ./trained-envs-executables/linux/Huggy/Huggy_BurstDebugInformation_DoNotShip/Data/Plugins/
#   inflating: ./trained-envs-executables/linux/Huggy/Huggy_BurstDebugInformation_DoNotShip/Data/Plugins/lib_burst_generated.txt
#    creating: ./trained-envs-executables/linux/Huggy/Huggy_Data/
#   inflating: ./trained-envs-executables/linux/Huggy/Huggy_Data/app.info
#   inflating: ./trained-envs-executables/linux/Huggy/Huggy_Data/boot.config
#   inflating: ./trained-envs-executables/linux/Huggy/Huggy_Data/globalgamemanagers
#   inflating: ./trained-envs-executables/linux/Huggy/Huggy_Data/globalgamemanagers.assets
# ...

# %%
# Removed redundant PATH modification
# import os
# os.environ['PATH'] += ':/root/.local/bin'
# !/usr/local/bin/mlagents-learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy2" --no-graphics
# Out:
# /bin/bash: line 1: /usr/local/bin/mlagents-learn: No such file or directory

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !which mlagents-push-to-hf

# %%
# !ls -l /usr/local/bin/ | grep mlagents
# !ls -l ./ml-agents/ml-agents/bin/ | grep mlagents
# !ls -l ./ml-agents/bin/ | grep mlagents
# Out:
# ls: cannot access './ml-agents/ml-agents/bin/': No such file or directory
# ls: cannot access './ml-agents/bin/': No such file or directory

# %%
# Removed redundant PATH modification
# import os
# os.environ['PATH'] += ':/root/.local/bin'
# !/usr/local/bin/mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy2" --repo-id="venky0310/huggy" --commit-message="Huggy"
# Out:
# /bin/bash: line 1: /usr/local/bin/mlagents-push-to-hf: No such file or directory
